# %% [markdown]
# # 5- Test the PCA class

# %%
from si.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from si.io.csv_file import read_csv

# %%
data = read_csv(r'C:\Users\anali\PycharmProjects\si\datasets\iris\iris.csv', sep=",", label=True, features=True)

# %%
n_components = 2
pca = PCA(n_components)
pca.fit_transform(data)
pca.components
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 n_components = 2
#       2 pca = PCA(n_components)
# ----> 3 pca.fit_transform(data)
#       4 pca.components
#
# File ~\PycharmProjects\si\src\si\decomposition\__init__.py:23, in PCA.fit_transform(self, X)
#      22 def fit_transform(self, X):
# ---> 23     self.fit(X)
#      24     return self.transform(X)
#
# File ~\PycharmProjects\si\src\si\decomposition\__init__.py:11, in PCA.fit(self, X)
#      10 def fit(self, X):
# ---> 11     self.mean = np.mean(X, axis=0)
#      12     X_centered = X - self.mean
#      13     U, S, Vt = np.linalg.svd(X_centered)
#
# File <__array_function__ internals>:200, in mean(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3464, in mean(a, axis, dtype, out, keepdims, where)
#    3461     else:
# ...

# %%
pca.explained_variance

# %%
pca.mean

# %%
#ata = pd.read_csv(r'C:\Users\anali\PycharmProjects\si\datasets\iris\iris.csv')

# Separate features (X) and labels (y)
X = data.iloc[:, :-1]
y = data['class']

# Map class labels to numbers
class_mapping = {
    'Iris-setosa': 0,
    'Iris-versicolor': 1,
    'Iris-virginica': 2
}
y_mapped = y.map(class_mapping)

# Standardize the data
scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)

# Instantiate and fit the PCA model
n_components = 2  # Choose the number of principal components
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_standardized)

# Plot the transformed data
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_mapped, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Iris Dataset')
plt.colorbar(label='Classes')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print( X_reduced)
#
# NameError: name 'X_reduced' is not defined
